# %% [markdown]
# ### Libraries

# %%
import pandas as pd
import numpy as np

from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Data

# %%
path = '/content/drive/MyDrive/Colab/Files/PROJECT/PROJETOFINAL_hoteis.csv'
data = pd.read_csv(path)

# %% [markdown]
# ### Opçoes

# %%
pd.set_option('display.max_columns', None)

# %% [markdown]
# ### Limpeza

# %%
data
# Out:
#     Unnamed: 0                    fsq_id  \
# 0            0  517fcb2be4b0d7e32b2c9a68
# 1            1  517089e9e4b0d21e986153c3
# 2            2  4f80f0bae4b0e160b9c9e122
# 3            3  598970be35f9830771f06b3f
# 4            4  5211312e11d259e1a2b3385a
# ..         ...                       ...
# 90          90  6021eac0dc86d61c512b9d92
# 91          91  513805a1e4b032c75badf416
# 92          92  4dd0e28452b1f8915bd0e895
# 93          93  4c5d77ad94fd0f470665cb45
# 94          94  4ebb8e0577c8d9bd1b9358cb
#
#                                            categories chains  distance  \
# 0   [{'id': 19010, 'name': 'Bed and Breakfast', 'i...     []       932
# 1   [{'id': 19014, 'name': 'Hotel', 'icon': {'pref...     []      2776
# 2   [{'id': 19014, 'name': 'Hotel', 'icon': {'pref...     []      2480
# 3   [{'id': 19010, 'name': 'Bed and Breakfast', 'i...     []      3106
# 4   [{'id': 19014, 'name': 'Hotel', 'icon': {'pref...     []      1969
# ...

# %%
data.isnull().sum()
# Out:
# Unnamed: 0                       0
# fsq_id                           0
# categories                       0
# chains                           0
# distance                         0
# link                             0
# name                             0
# timezone                         0
# geocodes.main.latitude           0
# geocodes.main.longitude          0
# geocodes.roof.latitude          18
# geocodes.roof.longitude         18
# location.address                 1
# location.country                 0
# location.cross_street           87
# location.formatted_address       0
# location.locality                1
# location.postcode                1
# location.region                  0
# related_places.children         29
# location.address_extended       66
# related_places.parent.fsq_id    85
# related_places.parent.name      85
# location.neighborhood           81
# popularity                       0
# rating                          28
# tastes                          60
# ...

# %% [markdown]
# ### Get rid of those goddamn Dots on column name

# %%
col = list(data.columns)
col
# Out:
# ['Unnamed: 0',
#  'fsq_id',
#  'categories',
#  'chains',
#  'distance',
#  'link',
#  'name',
#  'timezone',
#  'geocodes.main.latitude',
#  'geocodes.main.longitude',
#  'geocodes.roof.latitude',
#  'geocodes.roof.longitude',
#  'location.address',
#  'location.country',
#  'location.cross_street',
#  'location.formatted_address',
#  'location.locality',
#  'location.postcode',
#  'location.region',
#  'related_places.children',
#  'location.address_extended',
#  'related_places.parent.fsq_id',
#  'related_places.parent.name',
#  'location.neighborhood',
#  'popularity',
#  'rating',
#  'tastes',
#  'tips',
#  'verified',
#  'website',
#  'hours.display',
#  'hours.is_local_holiday',
#  'hours.open_now',
#  'hours.regular',
#  'hours.seasonal',
#  'social_media.facebook_id',
#  'social_media.twitter',
#  'description',
#  'social_media.instagram',
#  'price']

# %%
column_names = {}
col_new = []

for n, x in enumerate(data.columns):
  new = x.replace('.','_')
  col_new.append(new)

  column_names[col[n]] = col_new[n]

print('大丈夫')
# Out:
# 大丈夫

# %%
column_names
# Out:
# {'Unnamed: 0': 'Unnamed: 0',
#  'categories': 'categories',
#  'chains': 'chains',
#  'description': 'description',
#  'distance': 'distance',
#  'fsq_id': 'fsq_id',
#  'geocodes.main.latitude': 'geocodes_main_latitude',
#  'geocodes.main.longitude': 'geocodes_main_longitude',
#  'geocodes.roof.latitude': 'geocodes_roof_latitude',
#  'geocodes.roof.longitude': 'geocodes_roof_longitude',
#  'hours.display': 'hours_display',
#  'hours.is_local_holiday': 'hours_is_local_holiday',
#  'hours.open_now': 'hours_open_now',
#  'hours.regular': 'hours_regular',
#  'hours.seasonal': 'hours_seasonal',
#  'link': 'link',
#  'location.address': 'location_address',
#  'location.address_extended': 'location_address_extended',
#  'location.country': 'location_country',
#  'location.cross_street': 'location_cross_street',
#  'location.formatted_address': 'location_formatted_address',
#  'location.locality': 'location_locality',
#  'location.neighborhood': 'location_neighborhood',
# ...

# %%
data.rename(columns=column_names, inplace=True)

# %%
data.head()
# Out:
#    Unnamed: 0                    fsq_id  \
# 0           0  517fcb2be4b0d7e32b2c9a68
# 1           1  517089e9e4b0d21e986153c3
# 2           2  4f80f0bae4b0e160b9c9e122
# 3           3  598970be35f9830771f06b3f
# 4           4  5211312e11d259e1a2b3385a
#
#                                           categories chains  distance  \
# 0  [{'id': 19010, 'name': 'Bed and Breakfast', 'i...     []       932
# 1  [{'id': 19014, 'name': 'Hotel', 'icon': {'pref...     []      2776
# 2  [{'id': 19014, 'name': 'Hotel', 'icon': {'pref...     []      2480
# 3  [{'id': 19010, 'name': 'Bed and Breakfast', 'i...     []      3106
# 4  [{'id': 19014, 'name': 'Hotel', 'icon': {'pref...     []      1969
#
#                                   link  \
# 0  /v3/places/517fcb2be4b0d7e32b2c9a68
# 1  /v3/places/517089e9e4b0d21e986153c3
# 2  /v3/places/4f80f0bae4b0e160b9c9e122
# 3  /v3/places/598970be35f9830771f06b3f
# 4  /v3/places/5211312e11d259e1a2b3385a
#
# ...

# %% [markdown]
# ### Limpeza

# %%
data.isnull().sum()
# Out:
# Unnamed: 0                       0
# fsq_id                           0
# categories                       0
# chains                           0
# distance                         0
# link                             0
# name                             0
# timezone                         0
# geocodes_main_latitude           0
# geocodes_main_longitude          0
# geocodes_roof_latitude          18
# geocodes_roof_longitude         18
# location_address                 1
# location_country                 0
# location_cross_street           87
# location_formatted_address       0
# location_locality                1
# location_postcode                1
# location_region                  0
# related_places_children         29
# location_address_extended       66
# related_places_parent_fsq_id    85
# related_places_parent_name      85
# location_neighborhood           81
# popularity                       0
# rating                          28
# tastes                          60
# ...

# %%
# Colunas com 1 valor nulo
'''
location_address : 48
location_locality : 94 = Kamisu
location_postcode : 48
'''
# Out:
# '\nlocation_address : 48\nlocation_locality : 94 = Kamisu\nlocation_postcode : 48\n'

# %%
data[['location_locality','location_formatted_address', ]]
# Out:
#    location_locality                   location_formatted_address
# 0              Tokyo            外神田1丁目2-12, 千代田区, Tokyo, 101-0021
# 1            Chiyoda               紀尾井町1-2, 千代田区, Tokyo, 102-0094
# 2              Tokyo              上野7丁目2-16, 台東区, Tokyo, 110-0005
# 3              Tokyo              西浅草1丁目2-3, 台東区, Tokyo, 111-0035
# 4               Chuo              八重洲2丁目2-7, 中央区, Tokyo, 104-0028
# ..               ...                                          ...
# 90              Tama               鶴牧3丁目5-3, 多摩市, Tokyo, 206-0034
# 91          Kasukabe             立野276-1, 春日部市, Saitama, 344-0134
# 92          Jōsō-shi  水海道宝町1555-2 (水海道宝町), 常総市, Ibaraki, 303-0023
# 93          Kumagaya             籠原南1-123, 熊谷市, Saitama, 360-0847
# 94               NaN             太田129-23, 神栖市, Ibaraki, 314-0254
#
# [95 rows x 2 columns]

# %%
teste_pra_ver_um_negocio = pd.DataFrame(data.isnull().sum())

# %%
teste_pra_ver_um_negocio.T
# Out:
#    Unnamed: 0  fsq_id  categories  chains  distance  link  name  timezone  \
# 0           0       0           0       0         0     0     0         0
#
#    geocodes_main_latitude  geocodes_main_longitude  geocodes_roof_latitude  \
# 0                       0                        0                      18
#
#    geocodes_roof_longitude  location_address  location_country  \
# 0                       18                 1                 0
#
#    location_cross_street  location_formatted_address  location_locality  \
# 0                     87                           0                  1
#
#    location_postcode  location_region  related_places_children  \
# 0                  1                0                       29
#
#    location_address_extended  related_places_parent_fsq_id  \
# 0                         66                            85
#
#    related_places_parent_name  location_neighborhood  popularity  rating  \
# ...

# %%
data[data['location_locality'].isnull()]
# Out:
#     Unnamed: 0                    fsq_id  \
# 94          94  4ebb8e0577c8d9bd1b9358cb
#
#                                            categories chains  distance  \
# 94  [{'id': 19010, 'name': 'Bed and Breakfast', 'i...     []     88024
#
#                                    link  name    timezone  \
# 94  /v3/places/4ebb8e0577c8d9bd1b9358cb  鈴嘉旅館  Asia/Tokyo
#
#     geocodes_main_latitude  geocodes_main_longitude  geocodes_roof_latitude  \
# 94               35.818861               140.724906                     NaN
#
#     geocodes_roof_longitude location_address location_country  \
# 94                      NaN         太田129-23               JP
#
#    location_cross_street        location_formatted_address location_locality  \
# 94                   NaN  太田129-23, 神栖市, Ibaraki, 314-0254               NaN
#
#    location_postcode location_region related_places_children  \
# 94          314-0254         Ibaraki                     NaN
#
# ...

# %% [markdown]
# ### Drop useless columns

# %%
data.drop(columns=[ 'geocodes_roof_latitude',
                    'geocodes_roof_longitude',
                    'location_country',
                    'location_cross_street',
                    'location_address_extended',
                   	'related_places_parent_fsq_id',
                    'related_places_parent_name',
                    'location_neighborhood',
                    'description'], inplace=True)

# %% [markdown]
# ### Limpeza

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95 entries, 0 to 94
# Data columns (total 31 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Unnamed: 0                  95 non-null     int64
#  1   fsq_id                      95 non-null     object
#  2   categories                  95 non-null     object
#  3   chains                      95 non-null     object
#  4   distance                    95 non-null     int64
#  5   link                        95 non-null     object
#  6   name                        95 non-null     object
#  7   timezone                    95 non-null     object
#  8   geocodes_main_latitude      95 non-null     float64
#  9   geocodes_main_longitude     95 non-null     float64
#  10  location_address            94 non-null     object
#  11  location_formatted_address  95 non-null     object
#  12  location_locality           94 non-null     object
# ...

# %%
data.isnull().sum()
# Out:
# Unnamed: 0                     0
# fsq_id                         0
# categories                     0
# chains                         0
# distance                       0
# link                           0
# name                           0
# timezone                       0
# geocodes_main_latitude         0
# geocodes_main_longitude        0
# location_address               1
# location_formatted_address     0
# location_locality              1
# location_postcode              1
# location_region                0
# related_places_children       29
# popularity                     0
# rating                        28
# tastes                        60
# tips                           0
# verified                       0
# website                        5
# hours_display                 70
# hours_is_local_holiday         0
# hours_open_now                 0
# hours_regular                 70
# hours_seasonal                 0
# social_media_facebook_id      62
# ...

# %% [markdown]
# ### 'location_locality' Nulo para 'Kamisu'

# %%
data[data['location_locality'].isnull()]
# Out:
#     Unnamed: 0                    fsq_id  \
# 94          94  4ebb8e0577c8d9bd1b9358cb
#
#                                            categories chains  distance  \
# 94  [{'id': 19010, 'name': 'Bed and Breakfast', 'i...     []     88024
#
#                                    link  name    timezone  \
# 94  /v3/places/4ebb8e0577c8d9bd1b9358cb  鈴嘉旅館  Asia/Tokyo
#
#     geocodes_main_latitude  geocodes_main_longitude location_address  \
# 94               35.818861               140.724906         太田129-23
#
#           location_formatted_address location_locality location_postcode  \
# 94  太田129-23, 神栖市, Ibaraki, 314-0254               NaN          314-0254
#
#    location_region related_places_children  popularity  rating tastes tips  \
# 94         Ibaraki                     NaN    0.990899     NaN    NaN   []
#
#     verified website hours_display  hours_is_local_holiday  hours_open_now  \
# 94     False     NaN           NaN                   False           False
#
# ...

# %%
data[['location_address',	'location_formatted_address',	'location_locality',	'location_postcode',	'location_region']]
# Out:
#    location_address                   location_formatted_address  \
# 0        外神田1丁目2-12            外神田1丁目2-12, 千代田区, Tokyo, 101-0021
# 1           紀尾井町1-2               紀尾井町1-2, 千代田区, Tokyo, 102-0094
# 2         上野7丁目2-16              上野7丁目2-16, 台東区, Tokyo, 110-0005
# 3         西浅草1丁目2-3              西浅草1丁目2-3, 台東区, Tokyo, 111-0035
# 4         八重洲2丁目2-7              八重洲2丁目2-7, 中央区, Tokyo, 104-0028
# ..              ...                                          ...
# 90         鶴牧3丁目5-3               鶴牧3丁目5-3, 多摩市, Tokyo, 206-0034
# 91          立野276-1             立野276-1, 春日部市, Saitama, 344-0134
# 92      水海道宝町1555-2  水海道宝町1555-2 (水海道宝町), 常総市, Ibaraki, 303-0023
# 93         籠原南1-123             籠原南1-123, 熊谷市, Saitama, 360-0847
# 94         太田129-23             太田129-23, 神栖市, Ibaraki, 314-0254
#
#    location_locality location_postcode location_region
# 0              Tokyo          101-0021           Tokyo
# 1            Chiyoda          102-0094           Tokyo
# ...

# %%
data['location_region'].value_counts()
# Out:
# Tokyo       59
# Kanagawa    12
# Chiba        9
# Saitama      8
# Shizuoka     3
# Ibaraki      2
# Gunma        1
# Tochigi      1
# Name: location_region, dtype: int64

# %%
data['location_locality'].sort_values().unique().tolist()
# Out:
# ['Akiruno',
#  'Atami',
#  'Chiba',
#  'Chichibu',
#  'Chiyoda',
#  'Chuo',
#  'Fuchu',
#  'Fussa',
#  'Gotenba-shi',
#  'Inagi-shi',
#  'Jōsō-shi',
#  'Kasukabe',
#  'Katsuura',
#  'Kawasaki',
#  'Kumagaya',
#  'Kōtō',
#  'Machida',
#  'Meguro',
#  'Minato',
#  'Mishima',
#  'Musashino',
#  'Narita',
#  'Saitama-shi',
#  'Shibayama-machi',
#  'Shibuya',
#  'Shiki',
#  'Shinagawa',
#  'Shinjuku',
#  'Tachikawa-shi',
#  'Tama',
#  'Tokorozawa',
#  'Tokyo',
#  'Urayasu',
#  'Utsunomiya',
#  'Yokohama',
#  'Ōta',
#  nan]

# %%
data.iloc[94]['location_locality']
# Out:
# nan

# %%
data['location_locality'].fillna('Kamisu', inplace=True)

# %%
data.isnull().sum()
# Out:
# Unnamed: 0                     0
# fsq_id                         0
# categories                     0
# chains                         0
# distance                       0
# link                           0
# name                           0
# timezone                       0
# geocodes_main_latitude         0
# geocodes_main_longitude        0
# location_address               1
# location_formatted_address     0
# location_locality              0
# location_postcode              1
# location_region                0
# related_places_children       29
# popularity                     0
# rating                        28
# tastes                        60
# tips                           0
# verified                       0
# website                        5
# hours_display                 70
# hours_is_local_holiday         0
# hours_open_now                 0
# hours_regular                 70
# hours_seasonal                 0
# social_media_facebook_id      62
# ...

# %%
data.iloc[94]['location_locality']
# Out:
# 'Kamisu'

# %% [markdown]
# ### 'location_postcode' Nulo para '197-0011' & 'location_address' para ...
# Endereço: Crabb Ave, Fussa, Nishitama District, Tokyo, Tokyo 197-0011, Japan

# %%
data[data['location_postcode'].isnull()]
# Out:
#     Unnamed: 0                    fsq_id  \
# 48          48  4b50466ff964a520941f27e3
#
#                                            categories chains  distance  \
# 48  [{'id': 19014, 'name': 'Hotel', 'icon': {'pref...     []     38297
#
#                                    link                     name    timezone  \
# 48  /v3/places/4b50466ff964a520941f27e3  Kanto Lodge - Yokota AB  Asia/Tokyo
#
#     geocodes_main_latitude  geocodes_main_longitude location_address  \
# 48               35.747525               139.340509              NaN
#
#    location_formatted_address location_locality location_postcode  \
# 48                 福生市, Tokyo             Fussa               NaN
#
#    location_region related_places_children  popularity  rating tastes  \
# 48           Tokyo                     NaN     0.99452     7.6    NaN
#
#                                                  tips  verified website  \
# 48  [{'created_at': '2021-06-07T21:09:59.000Z', 't...     False     NaN
#
# ...

# %%
data.iloc[48]['location_postcode']
# Out:
# nan

# %%
data['location_postcode'].fillna('197-0011', inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95 entries, 0 to 94
# Data columns (total 31 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Unnamed: 0                  95 non-null     int64
#  1   fsq_id                      95 non-null     object
#  2   categories                  95 non-null     object
#  3   chains                      95 non-null     object
#  4   distance                    95 non-null     int64
#  5   link                        95 non-null     object
#  6   name                        95 non-null     object
#  7   timezone                    95 non-null     object
#  8   geocodes_main_latitude      95 non-null     float64
#  9   geocodes_main_longitude     95 non-null     float64
#  10  location_address            94 non-null     object
#  11  location_formatted_address  95 non-null     object
#  12  location_locality           95 non-null     object
# ...

# %%
data.iloc[48]['location_postcode']
# Out:
# '197-0011'

# %%
data[data['location_address'].isnull()]
# Out:
#     Unnamed: 0                    fsq_id  \
# 48          48  4b50466ff964a520941f27e3
#
#                                            categories chains  distance  \
# 48  [{'id': 19014, 'name': 'Hotel', 'icon': {'pref...     []     38297
#
#                                    link                     name    timezone  \
# 48  /v3/places/4b50466ff964a520941f27e3  Kanto Lodge - Yokota AB  Asia/Tokyo
#
#     geocodes_main_latitude  geocodes_main_longitude location_address  \
# 48               35.747525               139.340509              NaN
#
#    location_formatted_address location_locality location_postcode  \
# 48                 福生市, Tokyo             Fussa          197-0011
#
#    location_region related_places_children  popularity  rating tastes  \
# 48           Tokyo                     NaN     0.99452     7.6    NaN
#
#                                                  tips  verified website  \
# 48  [{'created_at': '2021-06-07T21:09:59.000Z', 't...     False     NaN
#
# ...

# %%
data.head() 
# Crabb Ave, Fussa, Nishitama District, Tokyo, Tokyo 197-0011, Japan
# Out:
#    Unnamed: 0                    fsq_id  \
# 0           0  517fcb2be4b0d7e32b2c9a68
# 1           1  517089e9e4b0d21e986153c3
# 2           2  4f80f0bae4b0e160b9c9e122
# 3           3  598970be35f9830771f06b3f
# 4           4  5211312e11d259e1a2b3385a
#
#                                           categories chains  distance  \
# 0  [{'id': 19010, 'name': 'Bed and Breakfast', 'i...     []       932
# 1  [{'id': 19014, 'name': 'Hotel', 'icon': {'pref...     []      2776
# 2  [{'id': 19014, 'name': 'Hotel', 'icon': {'pref...     []      2480
# 3  [{'id': 19010, 'name': 'Bed and Breakfast', 'i...     []      3106
# 4  [{'id': 19014, 'name': 'Hotel', 'icon': {'pref...     []      1969
#
#                                   link  \
# 0  /v3/places/517fcb2be4b0d7e32b2c9a68
# 1  /v3/places/517089e9e4b0d21e986153c3
# 2  /v3/places/4f80f0bae4b0e160b9c9e122
# 3  /v3/places/598970be35f9830771f06b3f
# 4  /v3/places/5211312e11d259e1a2b3385a
#
# ...

# %%
data['location_address'].fillna('Crabb Ave', inplace=True)

# %%
data.isnull().sum()
# Out:
# Unnamed: 0                     0
# fsq_id                         0
# categories                     0
# chains                         0
# distance                       0
# link                           0
# name                           0
# timezone                       0
# geocodes_main_latitude         0
# geocodes_main_longitude        0
# location_address               0
# location_formatted_address     0
# location_locality              0
# location_postcode              0
# location_region                0
# related_places_children       29
# popularity                     0
# rating                        28
# tastes                        60
# tips                           0
# verified                       0
# website                        5
# hours_display                 70
# hours_is_local_holiday         0
# hours_open_now                 0
# hours_regular                 70
# hours_seasonal                 0
# social_media_facebook_id      62
# ...

# %%
data
# Out:
#     Unnamed: 0                    fsq_id  \
# 0            0  517fcb2be4b0d7e32b2c9a68
# 1            1  517089e9e4b0d21e986153c3
# 2            2  4f80f0bae4b0e160b9c9e122
# 3            3  598970be35f9830771f06b3f
# 4            4  5211312e11d259e1a2b3385a
# ..         ...                       ...
# 90          90  6021eac0dc86d61c512b9d92
# 91          91  513805a1e4b032c75badf416
# 92          92  4dd0e28452b1f8915bd0e895
# 93          93  4c5d77ad94fd0f470665cb45
# 94          94  4ebb8e0577c8d9bd1b9358cb
#
#                                            categories chains  distance  \
# 0   [{'id': 19010, 'name': 'Bed and Breakfast', 'i...     []       932
# 1   [{'id': 19014, 'name': 'Hotel', 'icon': {'pref...     []      2776
# 2   [{'id': 19014, 'name': 'Hotel', 'icon': {'pref...     []      2480
# 3   [{'id': 19010, 'name': 'Bed and Breakfast', 'i...     []      3106
# 4   [{'id': 19014, 'name': 'Hotel', 'icon': {'pref...     []      1969
# ...

# %% [markdown]
# ### Criar DataFrame com coordenadas pra acessar restaurantes brasileiros

# %%
hotel_coord = data[['name', 'geocodes_main_latitude',	'geocodes_main_longitude']]

# %%
# hotel_coord.to_csv('/content/drive/MyDrive/Colab/Files/PROJECT/FINALPROJECT_hotel_coordinates.csv')

# %% [markdown]
# ## Restaurantes Brasileiros

# %% [markdown]
# ### Limpeza

# %%
brasil = pd.read_csv('/content/drive/MyDrive/Colab/Files/PROJECT/PROJETOFINAL_restaurantes.csv')
brasil
# Out:
#     Unnamed: 0                    fsq_id  \
# 0            0  505fce2be4b0a054473fa2eb
# 1            1  b91c2784f0b44e826bdfef64
# 2            2  40a90c773f0d4e7d9b05426c
# 3            3  56738a44498e84771b21395a
# 4            4  e91ed07f7ad74c3ca56dfe6c
# ..         ...                       ...
# 93          93  0cdac660a52e474cbae5cdbc
# 94          94  5f0d3896938b7c3b5e5fa837
# 95          95  0cdac660a52e474cbae5cdbc
# 96          96  535a620411d212a99bebe77b
# 97          97  0cdac660a52e474cbae5cdbc
#
#                                            categories chains  distance  \
# 0   [{'id': 13079, 'name': 'Brazilian Restaurant',...     []     734.0
# 1   [{'id': 13003, 'name': 'Bar', 'icon': {'prefix...     []     372.0
# 2   [{'id': 13031, 'name': 'Burger Joint', 'icon':...     []     383.0
# 3   [{'id': 13079, 'name': 'Brazilian Restaurant',...     []     432.0
# 4   [{'id': 13003, 'name': 'Bar', 'icon': {'prefix...     []     756.0
# ...

# %%
brasil.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 98 entries, 0 to 97
# Data columns (total 42 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Unnamed: 0                    98 non-null     int64
#  1   fsq_id                        98 non-null     object
#  2   categories                    98 non-null     object
#  3   chains                        98 non-null     object
#  4   distance                      98 non-null     float64
#  5   link                          98 non-null     object
#  6   name                          98 non-null     object
#  7   timezone                      58 non-null     object
#  8   geocodes.main.latitude        98 non-null     float64
#  9   geocodes.main.longitude       98 non-null     float64
#  10  geocodes.roof.latitude        81 non-null     float64
#  11  geocodes.roof.longitude       81 non-null     float64
# ...

# %%
brasil.isnull().sum()
# Out:
# Unnamed: 0                       0
# fsq_id                           0
# categories                       0
# chains                           0
# distance                         0
# link                             0
# name                             0
# timezone                        40
# geocodes.main.latitude           0
# geocodes.main.longitude          0
# geocodes.roof.latitude          17
# geocodes.roof.longitude         17
# location.address                 5
# location.country                 0
# location.cross_street           51
# location.formatted_address       0
# location.locality                3
# location.postcode                5
# location.region                  0
# location.neighborhood           83
# popularity                      40
# price                           40
# tips                             0
# verified                         0
# hours.is_local_holiday           0
# hours.open_now                   0
# hours.seasonal                   0
# ...

# %% [markdown]
# ### Transformar ' . ' em '_' aos nomes de colunas

# %%
col = list(brasil.columns)
col
# Out:
# ['Unnamed: 0',
#  'fsq_id',
#  'categories',
#  'chains',
#  'distance',
#  'link',
#  'name',
#  'timezone',
#  'geocodes.main.latitude',
#  'geocodes.main.longitude',
#  'geocodes.roof.latitude',
#  'geocodes.roof.longitude',
#  'location.address',
#  'location.country',
#  'location.cross_street',
#  'location.formatted_address',
#  'location.locality',
#  'location.postcode',
#  'location.region',
#  'location.neighborhood',
#  'popularity',
#  'price',
#  'tips',
#  'verified',
#  'hours.is_local_holiday',
#  'hours.open_now',
#  'hours.seasonal',
#  'social_media.twitter',
#  'website',
#  'hours.display',
#  'hours.regular',
#  'hotel',
#  'hotel_latitude',
#  'hotel_longitude',
#  'location.address_extended',
#  'rating',
#  'related_places.parent.fsq_id',
#  'related_places.parent.name',
#  'description',
#  'tastes',
#  'social_media.facebook_id',
#  'social_media.instagram']

# %%
column_names = {}
col_new = []

for n, x in enumerate(brasil.columns):
  new = x.replace('.','_')
  col_new.append(new)

  column_names[col[n]] = col_new[n]

print('daijoubu')
# Out:
# daijoubu

# %%
column_names
# Out:
# {'Unnamed: 0': 'Unnamed: 0',
#  'categories': 'categories',
#  'chains': 'chains',
#  'description': 'description',
#  'distance': 'distance',
#  'fsq_id': 'fsq_id',
#  'geocodes.main.latitude': 'geocodes_main_latitude',
#  'geocodes.main.longitude': 'geocodes_main_longitude',
#  'geocodes.roof.latitude': 'geocodes_roof_latitude',
#  'geocodes.roof.longitude': 'geocodes_roof_longitude',
#  'hotel': 'hotel',
#  'hotel_latitude': 'hotel_latitude',
#  'hotel_longitude': 'hotel_longitude',
#  'hours.display': 'hours_display',
#  'hours.is_local_holiday': 'hours_is_local_holiday',
#  'hours.open_now': 'hours_open_now',
#  'hours.regular': 'hours_regular',
#  'hours.seasonal': 'hours_seasonal',
#  'link': 'link',
#  'location.address': 'location_address',
#  'location.address_extended': 'location_address_extended',
#  'location.country': 'location_country',
#  'location.cross_street': 'location_cross_street',
#  'location.formatted_address': 'location_formatted_address',
# ...

# %%
brasil.rename(columns=column_names, inplace=True)

# %%
brasil.head(2)
# Out:
#    Unnamed: 0                    fsq_id  \
# 0           0  505fce2be4b0a054473fa2eb
# 1           1  b91c2784f0b44e826bdfef64
#
#                                           categories chains  distance  \
# 0  [{'id': 13079, 'name': 'Brazilian Restaurant',...     []     734.0
# 1  [{'id': 13003, 'name': 'Bar', 'icon': {'prefix...     []     372.0
#
#                                   link                    name    timezone  \
# 0  /v3/places/505fce2be4b0a054473fa2eb                 SAUDADE  Asia/Tokyo
# 1  /v3/places/b91c2784f0b44e826bdfef64  TUCANO'S GRILL and BAR         NaN
#
#    geocodes_main_latitude  geocodes_main_longitude  geocodes_roof_latitude  \
# 0               35.703322               139.765882               35.703322
# 1               35.698788               139.774789               35.698788
#
#    geocodes_roof_longitude location_address location_country  \
# 0               139.765882        湯島2丁目3-14               JP
# ...

# %% [markdown]
# ### Limpeza

# %%
brasil.isnull().sum()
# Out:
# Unnamed: 0                       0
# fsq_id                           0
# categories                       0
# chains                           0
# distance                         0
# link                             0
# name                             0
# timezone                        40
# geocodes_main_latitude           0
# geocodes_main_longitude          0
# geocodes_roof_latitude          17
# geocodes_roof_longitude         17
# location_address                 5
# location_country                 0
# location_cross_street           51
# location_formatted_address       0
# location_locality                3
# location_postcode                5
# location_region                  0
# location_neighborhood           83
# popularity                      40
# price                           40
# tips                             0
# verified                         0
# hours_is_local_holiday           0
# hours_open_now                   0
# hours_seasonal                   0
# ...

# %%
brasil[brasil['location_postcode'].isnull()]
# Out:
#     Unnamed: 0                    fsq_id  \
# 0            0  505fce2be4b0a054473fa2eb
# 27          27  4e0f02e17d8bb178a8ae4e52
# 29          29  4e0f02e17d8bb178a8ae4e52
# 48          48  8c1c030fe8db4f5b6a601481
# 72          72  505fce2be4b0a054473fa2eb
#
#                                            categories chains  distance  \
# 0   [{'id': 13079, 'name': 'Brazilian Restaurant',...     []     734.0
# 27  [{'id': 13079, 'name': 'Brazilian Restaurant',...     []     485.0
# 29  [{'id': 13079, 'name': 'Brazilian Restaurant',...     []     733.0
# 48  [{'id': 13079, 'name': 'Brazilian Restaurant',...     []     208.0
# 72  [{'id': 13079, 'name': 'Brazilian Restaurant',...     []     769.0
#
#                                    link             name    timezone  \
# 0   /v3/places/505fce2be4b0a054473fa2eb          SAUDADE  Asia/Tokyo
# 27  /v3/places/4e0f02e17d8bb178a8ae4e52  Copacabana 3355  Asia/Tokyo
# 29  /v3/places/4e0f02e17d8bb178a8ae4e52  Copacabana 3355  Asia/Tokyo
# ...

# %%
brasil.columns
# Out:
# Index(['Unnamed: 0', 'fsq_id', 'categories', 'chains', 'distance', 'link',
#        'name', 'timezone', 'geocodes_main_latitude', 'geocodes_main_longitude',
#        'geocodes_roof_latitude', 'geocodes_roof_longitude', 'location_address',
#        'location_country', 'location_cross_street',
#        'location_formatted_address', 'location_locality', 'location_postcode',
#        'location_region', 'location_neighborhood', 'popularity', 'price',
#        'tips', 'verified', 'hours_is_local_holiday', 'hours_open_now',
#        'hours_seasonal', 'social_media_twitter', 'website', 'hours_display',
#        'hours_regular', 'hotel', 'hotel_latitude', 'hotel_longitude',
#        'location_address_extended', 'rating', 'related_places_parent_fsq_id',
#        'related_places_parent_name', 'description', 'tastes',
#        'social_media_facebook_id', 'social_media_instagram'],
#       dtype='object')

# %%
brasil[['location_address', 'location_country', 'location_cross_street', 'location_formatted_address', 'location_locality', 'location_postcode', 'location_region']]
# Out:
#    location_address location_country location_cross_street  \
# 0         湯島2丁目3-14               JP              エムサ湯島 1F
# 1          神田花岡町1-1               JP                   NaN
# 2            神田花岡町1               JP                   NaN
# 3         赤坂3丁目10-4               JP              風月堂ビル 5F
# 4             四谷2-2               JP                   NaN
# ..              ...              ...                   ...
# 93      神奈川区金港町1-10               JP                   NaN
# 94       西区南幸1丁目1-1               JP             B3F ハマチカ内
# 95      神奈川区金港町1-10               JP                   NaN
# 96      神奈川区金港町1-10               JP          横浜ベイクォーター 3F
# 97      神奈川区金港町1-10               JP                   NaN
#
#                            location_formatted_address location_locality  \
# 0                    湯島2丁目3-14 (エムサ湯島 1F), 文京区, Tokyo             Tokyo
# 1                       神田花岡町1-1, 千代田区, 東京都, 101-0028              千代田区
# ...

# %% [markdown]
# ### 'location_region' into romaji

# %%
brasil['location_region'].unique()
# Out:
# array(['Tokyo', '東京都', 'Chiba', 'Kanagawa', '神奈川県', '千葉県'], dtype=object)

# %%
data['location_region'].unique()
# Out:
# array(['Tokyo', 'Chiba', 'Kanagawa', 'Saitama', 'Gunma', 'Shizuoka',
#        'Tochigi', 'Ibaraki'], dtype=object)

# %%
ken = { '千葉県':'Chiba',
        '群馬県':'Gunma',
        '東京都':'Tokyo',
        '神奈川県':'Kanagawa',
        '埼玉県':'Saitama',
        '栃木県':'Tochigi'}

# %%
brasil['location_region'].replace(ken, inplace=True)

# %%
brasil['location_region'].unique()
# Out:
# array(['Tokyo', 'Chiba', 'Kanagawa'], dtype=object)

# %% [markdown]
# ### 'location_locality' into romaji

# %%
brasil['location_locality'].unique()
# Out:
# array(['Tokyo', '千代田区', '新宿区', 'Taitō', 'Chiyoda', 'Chuo', 'Urayasu',
#        'Yokohama', nan, '横浜市', 'Roppongi', 'Tachikawa-shi', "Jin'nan",
#        '渋谷区', '港区', 'Kawasaki', 'Narita-shi', '成田市', '豊島区', 'Ōta', '大田区'],
#       dtype=object)

# %%
data['location_locality'].unique()
# Out:
# array(['Tokyo', 'Chiyoda', 'Chuo', 'Urayasu', 'Kawasaki', 'Minato',
#        'Shinagawa', 'Machida', 'Meguro', 'Yokohama', 'Kōtō',
#        'Saitama-shi', 'Tachikawa-shi', 'Shibayama-machi', 'Narita', 'Ōta',
#        'Katsuura', 'Shibuya', 'Chichibu', 'Fussa', 'Gotenba-shi',
#        'Utsunomiya', 'Akiruno', 'Shiki', 'Atami', 'Chiba', 'Mishima',
#        'Shinjuku', 'Musashino', 'Inagi-shi', 'Fuchu', 'Tokorozawa',
#        'Tama', 'Kasukabe', 'Jōsō-shi', 'Kumagaya', 'Kamisu'], dtype=object)

# %%
shi = { '成田市':'Narita',
        '邑楽郡':'Ōra-gun',
        '千代田区':'Chiyoda',
        '新宿区':'Shinjuku',
        '港区':'Minato',
        '豊島区':'Toshima',
        '渋谷区':'Shibuya',
        '葛飾区':'Katsushika',
        '世田谷区':'Setagaya',
        '横浜市':'Yokohama',
        'さいたま市':'Saitama',
        '八千代市':'Yachio',
        '千葉市':'Chiba',
        '川越市':'Arihara',
        '我孫子市':'Abiko',
        '市原市':'Ichihara',
        '久喜市':'Kuki',
        '平塚市':'Hiratsuka',
        '館林市':'Tatebayashi-shi',
        '太田市':'Oota',
        '大田区':'Oota-ku',
        '真岡市':'Mooka',
        '伊勢崎市':'Isesaki'}

# %%
brasil['location_locality'].replace(shi, inplace=True)

# %%
brasil['location_locality'].unique()
# Out:
# array(['Tokyo', 'Chiyoda', 'Shinjuku', 'Taitō', 'Chuo', 'Urayasu',
#        'Yokohama', nan, 'Roppongi', 'Tachikawa-shi', "Jin'nan", 'Shibuya',
#        'Minato', 'Kawasaki', 'Narita-shi', 'Narita', 'Toshima', 'Ōta',
#        'Oota-ku'], dtype=object)

# %% [markdown]
# ### 'location_postcode' Nulo

# %%
brasil[brasil['location_postcode'].isnull()]
# Out:
#     Unnamed: 0                    fsq_id  \
# 0            0  505fce2be4b0a054473fa2eb
# 27          27  4e0f02e17d8bb178a8ae4e52
# 29          29  4e0f02e17d8bb178a8ae4e52
# 48          48  8c1c030fe8db4f5b6a601481
# 72          72  505fce2be4b0a054473fa2eb
#
#                                            categories chains  distance  \
# 0   [{'id': 13079, 'name': 'Brazilian Restaurant',...     []     734.0
# 27  [{'id': 13079, 'name': 'Brazilian Restaurant',...     []     485.0
# 29  [{'id': 13079, 'name': 'Brazilian Restaurant',...     []     733.0
# 48  [{'id': 13079, 'name': 'Brazilian Restaurant',...     []     208.0
# 72  [{'id': 13079, 'name': 'Brazilian Restaurant',...     []     769.0
#
#                                    link             name    timezone  \
# 0   /v3/places/505fce2be4b0a054473fa2eb          SAUDADE  Asia/Tokyo
# 27  /v3/places/4e0f02e17d8bb178a8ae4e52  Copacabana 3355  Asia/Tokyo
# 29  /v3/places/4e0f02e17d8bb178a8ae4e52  Copacabana 3355  Asia/Tokyo
# ...

# %%
brasil.iloc[0]
# Out:
# Unnamed: 0                                                                      0
# fsq_id                                                   505fce2be4b0a054473fa2eb
# categories                      [{'id': 13079, 'name': 'Brazilian Restaurant',...
# chains                                                                         []
# distance                                                                    734.0
# link                                          /v3/places/505fce2be4b0a054473fa2eb
# name                                                                      SAUDADE
# timezone                                                               Asia/Tokyo
# geocodes_main_latitude                                                  35.703322
# geocodes_main_longitude                                                139.765882
# geocodes_roof_latitude                                                  35.703322
# ...

# %%
brasil['location_postcode'][0] = '113-0034'
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
brasil['location_postcode'][0]
# Out:
# '113-0034'

# %% [markdown]
# ### Other Nulos

# %%
brasil.iloc[27]
# 27 : 3 Chome Sumiyoshicho, Naka Ward, Yokohama, Kanagawa 231-0013, Japan
# Out:
# Unnamed: 0                                                                     27
# fsq_id                                                   4e0f02e17d8bb178a8ae4e52
# categories                      [{'id': 13079, 'name': 'Brazilian Restaurant',...
# chains                                                                         []
# distance                                                                    485.0
# link                                          /v3/places/4e0f02e17d8bb178a8ae4e52
# name                                                              Copacabana 3355
# timezone                                                               Asia/Tokyo
# geocodes_main_latitude                                                  35.446283
# geocodes_main_longitude                                                139.637295
# geocodes_roof_latitude                                                  35.446283
# ...

# %%
brasil['location_address'][27] = '3 Chome Sumiyoshicho'
brasil['location_postcode'][27] = '231-0013'
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
brasil.iloc[29]
# 29 : 3 Chome Sumiyoshicho, Naka Ward, Yokohama, Kanagawa 231-0013, Japan
# Out:
# Unnamed: 0                                                                     29
# fsq_id                                                   4e0f02e17d8bb178a8ae4e52
# categories                      [{'id': 13079, 'name': 'Brazilian Restaurant',...
# chains                                                                         []
# distance                                                                    733.0
# link                                          /v3/places/4e0f02e17d8bb178a8ae4e52
# name                                                              Copacabana 3355
# timezone                                                               Asia/Tokyo
# geocodes_main_latitude                                                  35.446283
# geocodes_main_longitude                                                139.637295
# geocodes_roof_latitude                                                  35.446283
# ...

# %%
brasil['location_address'][29] = '3 Chome Sumiyoshicho'
brasil['location_postcode'][29] = '231-0013'
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
brasil.iloc[48]
# 48 : 1-chōme-17 Dōgenzaka, Shibuya City, Tokyo 150-0043, Japan
# Out:
# Unnamed: 0                                                                     48
# fsq_id                                                   8c1c030fe8db4f5b6a601481
# categories                      [{'id': 13079, 'name': 'Brazilian Restaurant',...
# chains                                                                         []
# distance                                                                    208.0
# link                                          /v3/places/8c1c030fe8db4f5b6a601481
# name                                                                  ブレン・ブレン・ブレン
# timezone                                                                      NaN
# geocodes_main_latitude                                                  35.657092
# geocodes_main_longitude                                                139.697088
# geocodes_roof_latitude                                                  35.657092
# ...

# %%
brasil['location_postcode'][48] = '150-0043'
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
brasil.iloc[72]
# 72 : 2-chōme-3 Yushima, Bunkyo City, Tokyo 113-0034, Japan
# Out:
# Unnamed: 0                                                                     72
# fsq_id                                                   505fce2be4b0a054473fa2eb
# categories                      [{'id': 13079, 'name': 'Brazilian Restaurant',...
# chains                                                                         []
# distance                                                                    769.0
# link                                          /v3/places/505fce2be4b0a054473fa2eb
# name                                                                      SAUDADE
# timezone                                                               Asia/Tokyo
# geocodes_main_latitude                                                  35.703322
# geocodes_main_longitude                                                139.765882
# geocodes_roof_latitude                                                  35.703322
# ...

# %%
brasil['location_postcode'][72] = '113-0034'
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# ### Limpeza

# %%
brasil.isnull().sum()
# Out:
# Unnamed: 0                       0
# fsq_id                           0
# categories                       0
# chains                           0
# distance                         0
# link                             0
# name                             0
# timezone                        40
# geocodes_main_latitude           0
# geocodes_main_longitude          0
# geocodes_roof_latitude          17
# geocodes_roof_longitude         17
# location_address                 3
# location_country                 0
# location_cross_street           51
# location_formatted_address       0
# location_locality                3
# location_postcode                0
# location_region                  0
# location_neighborhood           83
# popularity                      40
# price                           40
# tips                             0
# verified                         0
# hours_is_local_holiday           0
# hours_open_now                   0
# hours_seasonal                   0
# ...

# %% [markdown]
# ### 'location_address' Nulo

# %%
brasil[brasil['location_address'].isnull()]
# Out:
#     Unnamed: 0                    fsq_id  \
# 8            8  5c3dcf2c4c954c002c09b806
# 38          38  6039c959ab44fd74e65bfc17
# 56          56  5c3dcf2c4c954c002c09b806
#
#                                            categories chains  distance  \
# 8   [{'id': 13079, 'name': 'Brazilian Restaurant',...     []     280.0
# 38  [{'id': 13079, 'name': 'Brazilian Restaurant',...     []     305.0
# 56  [{'id': 13079, 'name': 'Brazilian Restaurant',...     []     632.0
#
#                                    link      name    timezone  \
# 8   /v3/places/5c3dcf2c4c954c002c09b806  Cantinho  Asia/Tokyo
# 38  /v3/places/6039c959ab44fd74e65bfc17   Alegria  Asia/Tokyo
# 56  /v3/places/5c3dcf2c4c954c002c09b806  Cantinho  Asia/Tokyo
#
#     geocodes_main_latitude  geocodes_main_longitude  geocodes_roof_latitude  \
# 8                35.679147               139.772888               35.679147
# 38               35.697260               139.412280                     NaN
# ...

# %%
# 8 : 3-chōme-5 Nihonbashi, Chuo City, Tokyo 103-0027, Japan
# 38 : 3-chōme-1 Shibasakichō, Tachikawa, Tokyo 190-0023, Japan
# 56 : 3-chōme-5 Nihonbashi, Chuo City, Tokyo 103-0027, Japan

# %%
brasil['location_address'][8] = '3-chōme-5 Nihonbashi'
brasil['location_address'][38] = '3-chōme-1 Shibasakichō'
brasil['location_address'][56] = '3-chōme-5 Nihonbashi'
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %% [markdown]
# ### 'location_locality' Nulo

# %%
brasil[brasil['location_locality'].isnull()]
# Out:
#     Unnamed: 0                    fsq_id  \
# 22          22  5f0d3896938b7c3b5e5fa837
# 92          92  5f0d3896938b7c3b5e5fa837
# 94          94  5f0d3896938b7c3b5e5fa837
#
#                                            categories chains  distance  \
# 22  [{'id': 13079, 'name': 'Brazilian Restaurant',...     []     314.0
# 92  [{'id': 13079, 'name': 'Brazilian Restaurant',...     []     258.0
# 94  [{'id': 13079, 'name': 'Brazilian Restaurant',...     []     405.0
#
#                                    link              name    timezone  \
# 22  /v3/places/5f0d3896938b7c3b5e5fa837  Rio grande Grill  Asia/Tokyo
# 92  /v3/places/5f0d3896938b7c3b5e5fa837  Rio grande Grill  Asia/Tokyo
# 94  /v3/places/5f0d3896938b7c3b5e5fa837  Rio grande Grill  Asia/Tokyo
#
#     geocodes_main_latitude  geocodes_main_longitude  geocodes_roof_latitude  \
# 22               35.466548               139.622226               35.466548
# ...

# %%
brasil['location_locality'].unique()
# Out:
# array(['Tokyo', 'Chiyoda', 'Shinjuku', 'Taitō', 'Chuo', 'Urayasu',
#        'Yokohama', nan, 'Roppongi', 'Tachikawa-shi', "Jin'nan", 'Shibuya',
#        'Minato', 'Kawasaki', 'Narita-shi', 'Narita', 'Toshima', 'Ōta',
#        'Oota-ku'], dtype=object)

# %%
brasil['location_locality'][22] = 'Yokohama'
brasil['location_locality'][92] = 'Yokohama'
brasil['location_locality'][94] = 'Yokohama'
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
brasil.isnull().sum()
# Out:
# Unnamed: 0                       0
# fsq_id                           0
# categories                       0
# chains                           0
# distance                         0
# link                             0
# name                             0
# timezone                        40
# geocodes_main_latitude           0
# geocodes_main_longitude          0
# geocodes_roof_latitude          17
# geocodes_roof_longitude         17
# location_address                 0
# location_country                 0
# location_cross_street           51
# location_formatted_address       0
# location_locality                0
# location_postcode                0
# location_region                  0
# location_neighborhood           83
# popularity                      40
# price                           40
# tips                             0
# verified                         0
# hours_is_local_holiday           0
# hours_open_now                   0
# hours_seasonal                   0
# ...

# %% [markdown]
# ### Timezone é igual no japao

# %%
brasil['timezone'].fillna(brasil['timezone'].mode()[0], inplace=True)

# %%
brasil['timezone'].value_counts()
# Out:
# Asia/Tokyo    98
# Name: timezone, dtype: int64

# %% [markdown]
# ### Resultado dos DataFrames

# %%
data
# Out:
#     Unnamed: 0                    fsq_id  \
# 0            0  517fcb2be4b0d7e32b2c9a68
# 1            1  517089e9e4b0d21e986153c3
# 2            2  4f80f0bae4b0e160b9c9e122
# 3            3  598970be35f9830771f06b3f
# 4            4  5211312e11d259e1a2b3385a
# ..         ...                       ...
# 90          90  6021eac0dc86d61c512b9d92
# 91          91  513805a1e4b032c75badf416
# 92          92  4dd0e28452b1f8915bd0e895
# 93          93  4c5d77ad94fd0f470665cb45
# 94          94  4ebb8e0577c8d9bd1b9358cb
#
#                                            categories chains  distance  \
# 0   [{'id': 19010, 'name': 'Bed and Breakfast', 'i...     []       932
# 1   [{'id': 19014, 'name': 'Hotel', 'icon': {'pref...     []      2776
# 2   [{'id': 19014, 'name': 'Hotel', 'icon': {'pref...     []      2480
# 3   [{'id': 19010, 'name': 'Bed and Breakfast', 'i...     []      3106
# 4   [{'id': 19014, 'name': 'Hotel', 'icon': {'pref...     []      1969
# ...

# %%
brasil
# Out:
#     Unnamed: 0                    fsq_id  \
# 0            0  505fce2be4b0a054473fa2eb
# 1            1  b91c2784f0b44e826bdfef64
# 2            2  40a90c773f0d4e7d9b05426c
# 3            3  56738a44498e84771b21395a
# 4            4  e91ed07f7ad74c3ca56dfe6c
# ..         ...                       ...
# 93          93  0cdac660a52e474cbae5cdbc
# 94          94  5f0d3896938b7c3b5e5fa837
# 95          95  0cdac660a52e474cbae5cdbc
# 96          96  535a620411d212a99bebe77b
# 97          97  0cdac660a52e474cbae5cdbc
#
#                                            categories chains  distance  \
# 0   [{'id': 13079, 'name': 'Brazilian Restaurant',...     []     734.0
# 1   [{'id': 13003, 'name': 'Bar', 'icon': {'prefix...     []     372.0
# 2   [{'id': 13031, 'name': 'Burger Joint', 'icon':...     []     383.0
# 3   [{'id': 13079, 'name': 'Brazilian Restaurant',...     []     432.0
# 4   [{'id': 13003, 'name': 'Bar', 'icon': {'prefix...     []     756.0
# ...

# %% [markdown]
# # ToDo s
#
# * drop useless columns;
# * locality duplicada;
# * folium
# *

# %%
data.head(1)
# Out:
#    Unnamed: 0                    fsq_id  \
# 0           0  517fcb2be4b0d7e32b2c9a68
#
#                                           categories chains  distance  \
# 0  [{'id': 19010, 'name': 'Bed and Breakfast', 'i...     []       932
#
#                                   link                         name  \
# 0  /v3/places/517fcb2be4b0d7e32b2c9a68  Anshin Oyado (安心お宿 秋葉原電気街店)
#
#      timezone  geocodes_main_latitude  geocodes_main_longitude  \
# 0  Asia/Tokyo               35.697955               139.770792
#
#   location_address         location_formatted_address location_locality  \
# 0       外神田1丁目2-12  外神田1丁目2-12, 千代田区, Tokyo, 101-0021             Tokyo
#
#   location_postcode location_region related_places_children  popularity  \
# 0          101-0021           Tokyo                      []    0.992807
#
#    rating             tastes  \
# 0     9.2  ['hotel', 'cozy']
#
#                                                 tips  verified  \
# ...

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'fsq_id', 'categories', 'chains', 'distance', 'link',
#        'name', 'timezone', 'geocodes_main_latitude', 'geocodes_main_longitude',
#        'location_address', 'location_formatted_address', 'location_locality',
#        'location_postcode', 'location_region', 'related_places_children',
#        'popularity', 'rating', 'tastes', 'tips', 'verified', 'website',
#        'hours_display', 'hours_is_local_holiday', 'hours_open_now',
#        'hours_regular', 'hours_seasonal', 'social_media_facebook_id',
#        'social_media_twitter', 'social_media_instagram', 'price'],
#       dtype='object')

# %%
data.shape
# Out:
# (95, 31)

# %% [markdown]
# ### 'related_places_children' de valor '[]' para NaN

# %%
data['related_places_children'][data['related_places_children']=='[]'] = np.NaN
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# ### Drop Useless columns

# %%
data['price'].isnull().sum()

# %%
data['tips'].isnull().sum()
# Out:
# 0

# %%
data['tips'][0]
# Out:
# "[{'created_at': '2019-04-24T07:37:54.000Z', 'text': '100点満点の神ホテルです😇'}, {'created_at': '2019-01-17T00:07:42.000Z', 'text': 'ロールスクリーンは完全な遮蔽にはなりません。室内の照明を点けると外から薄っすら透けて見えてしまいます。'}, {'created_at': '2019-01-17T00:07:15.000Z', 'text': '清潔感のある室内には3口の電源コンセントがあり、USB変換ACアダプタとスマホ用ケーブル（3分岐：USB Type C、USB Micro-B、Lightningコネクタ）も置かれていて非常に便利です。そのほかVOD見放題のTV、無料のペットボトルの水、鏡もついてます。'}, {'created_at': '2016-12-08T05:52:17.000Z', 'text': '夜行バスを降りた後やイベント後等にお風呂だけでも利用しやすいです'}, {'created_at': '2016-11-24T09:41:36.000Z', 'text': 'カプセルホテルとは思えない位にサービスが充実しています。JR秋葉原駅からも近くアクセスも良好。'}]"

# %%
data['tastes'].unique()
# Out:
# array(["['hotel', 'cozy']",
#        "['friendly staff', 'scenic views', 'hotel', 'buffet', 'luxury', 'modern rooms', 'Japanese breakfast', 'top floor']",
#        "['saunas', 'open-air bath', 'cold-water bath']", nan,
#        "['bath houses']",
#        "['beer', 'breakfast food', 'wifi', 'massage', 'spa', 'resorts', 'saunas', 'hot springs', 'fireworks']",
#        "['hotel', 'spa']",
#        "['hotel', 'wifi', 'rice', 'park', 'lounges', 'spacious', 'spacious rooms']",
#        "['breakfast food', 'sunsets', 'hotel', 'clean', 'croissants']",
#        "['hotel', 'clean', 'bread', 'cozy', 'comfortable']",
#        "['parking', 'quiet', 'soba', 'saunas', 'hot springs', 'bath houses', 'open-air bath']",
#        "['hotel', 'bath houses']",
#        "['Asian food', 'breakfast food', 'scenic views', 'hotel', 'cake', 'tea', 'rice', 'quiet', 'airports', 'buffet', 'malls', 'bus', 'lounges', '24-hour', 'cigars', 'beer gardens', 'halloween', 'fitness club']",
# ...

# %%
data['rating'].describe()
# Out:
# count    95.000000
# mean      0.989876
# std       0.008244
# min       0.960615
# 25%       0.986761
# 50%       0.992585
# 75%       0.995197
# max       0.998533
# Name: popularity, dtype: float64

# %%
data['rating'].describe()
# Out:
# count    67.000000
# mean      7.780597
# std       0.790711
# min       6.100000
# 25%       7.250000
# 50%       7.900000
# 75%       8.300000
# max       9.400000
# Name: rating, dtype: float64

# %%
data[data['rating'].isnull()]
# Out:
#     Unnamed: 0                    fsq_id  \
# 67          67  4c401b8eaf052d7f8c527b79
# 68          68  5d4a6f51b2eb7b0008473c17
# 69          69  5f6861060bfd233db3a6d086
# 70          70  5e368c17e5bac40007a6b735
# 71          71  4ba8ce17f964a52058f039e3
# 72          72  5decf9691a58910008344e01
# 73          73  5973564defa82a569354eefd
# 74          74  5f1b93f067564371a9124bcd
# 75          75  5c6d7da3033693002cc898e9
# 76          76  5d76e76503766000083b27c7
# 77          77  4d0007bfba1da1cd555c8628
# 78          78  5efc852c25dda600087ed372
# 79          79  4c9db7d30df79c742980191a
# 80          80  4de9f7ccb3ad083a33c2d34c
# 81          81  4bdf8bdb6316d13a26dba011
# 82          82  4f17afc0e4b0f1e7baa2d8c8
# 83          83  5d5650f0eb01dc00074a0e19
# 84          84  4ba2ae78f964a5209b0f38e3
# 85          85  57276b57498e7b86c5ae1e11
# 86          86  5f94b53ee85b1932a4cac151
# 87          87  603840c1ab44fd74e644ece8
# 88          88  5ed8f20aa93f0c0008001e5d
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95 entries, 0 to 94
# Data columns (total 16 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   fsq_id                      95 non-null     object
#  1   categories                  95 non-null     object
#  2   distance                    95 non-null     int64
#  3   link                        95 non-null     object
#  4   name                        95 non-null     object
#  5   geocodes_main_latitude      95 non-null     float64
#  6   geocodes_main_longitude     95 non-null     float64
#  7   location_address            95 non-null     object
#  8   location_formatted_address  95 non-null     object
#  9   location_locality           95 non-null     object
#  10  location_postcode           95 non-null     object
#  11  location_region             95 non-null     object
#  12  popularity                  95 non-null     float64
# ...

# %%
data.drop(columns=['Unnamed: 0', 'chains', 'timezone', 'related_places_children', 'verified', 'website', 'hours_display', 'hours_is_local_holiday', 'hours_open_now', 
      'hours_regular', 'hours_seasonal', 'social_media_facebook_id',
      'social_media_twitter', 'social_media_instagram', 'price'],inplace=True)

# %%
data.columns
# Out:
# Index(['fsq_id', 'categories', 'distance', 'link', 'name',
#        'geocodes_main_latitude', 'geocodes_main_longitude', 'location_address',
#        'location_formatted_address', 'location_locality', 'location_postcode',
#        'location_region', 'popularity', 'rating', 'tastes', 'tips'],
#       dtype='object')

# %%
data.head(1)
# Out:
#                      fsq_id  \
# 0  517fcb2be4b0d7e32b2c9a68
#
#                                           categories  distance  \
# 0  [{'id': 19010, 'name': 'Bed and Breakfast', 'i...       932
#
#                                   link                         name  \
# 0  /v3/places/517fcb2be4b0d7e32b2c9a68  Anshin Oyado (安心お宿 秋葉原電気街店)
#
#    geocodes_main_latitude  geocodes_main_longitude location_address  \
# 0               35.697955               139.770792       外神田1丁目2-12
#
#           location_formatted_address location_locality location_postcode  \
# 0  外神田1丁目2-12, 千代田区, Tokyo, 101-0021             Tokyo          101-0021
#
#   location_region  popularity  rating             tastes  \
# 0           Tokyo    0.992807     9.2  ['hotel', 'cozy']
#
#                                                 tips
# 0  [{'created_at': '2019-04-24T07:37:54.000Z', 't...

# %%
data.shape
# Out:
# (95, 16)

# %% [markdown]
# ### Drop useless columns from 'brasil'

# %%
pd.DataFrame(brasil.isnull().sum()).T
# Out:
#    Unnamed: 0  fsq_id  categories  chains  distance  link  name  timezone  \
# 0           0       0           0       0         0     0     0         0
#
#    geocodes_main_latitude  geocodes_main_longitude  geocodes_roof_latitude  \
# 0                       0                        0                      17
#
#    geocodes_roof_longitude  location_address  location_country  \
# 0                       17                 0                 0
#
#    location_cross_street  location_formatted_address  location_locality  \
# 0                     51                           0                  0
#
#    location_postcode  location_region  location_neighborhood  popularity  \
# 0                  0                0                     83          40
#
#    price  tips  verified  hours_is_local_holiday  hours_open_now  \
# 0     40     0         0                       0               0
#
#    hours_seasonal  social_media_twitter  website  hours_display  \
# ...

# %%
brasil['social_media_facebook_id']
# Out:
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
#           ...
# 93             NaN
# 94             NaN
# 95             NaN
# 96    2.599924e+14
# 97             NaN
# Name: social_media_facebook_id, Length: 98, dtype: float64

# %%
brasil['rating'].isnull().sum()
# Out:
# 82

# %%
brasil[~brasil['tastes'].isnull()]
# Out:
#     Unnamed: 0                    fsq_id  \
# 6            6  4bd574a94e32d13a20d0c080
# 21          21  535a620411d212a99bebe77b
# 31          31  4e6c86f91495f34925932762
# 40          40  528af03311d281c7eee110d4
# 41          41  53c0fa87498e6127c41f69b1
# 62          62  55530f91498eca9bfbb5737b
# 64          64  4c3fcb59520fa5930438c7ac
# 68          68  4e478a17887781a619b9fd99
# 74          74  4e6c86f91495f34925932762
# 85          85  55530f91498eca9bfbb5737b
# 89          89  4c3fcb59520fa5930438c7ac
# 91          91  535a620411d212a99bebe77b
# 96          96  535a620411d212a99bebe77b
#
#                                            categories chains  distance  \
# 6   [{'id': 13079, 'name': 'Brazilian Restaurant',...     []     627.0
# 21  [{'id': 13026, 'name': 'BBQ Joint', 'icon': {'...     []     287.0
# 31  [{'id': 13079, 'name': 'Brazilian Restaurant',...     []     390.0
# 40  [{'id': 13079, 'name': 'Brazilian Restaurant',...     []     724.0
# ...

# %%
brasil['hours_regular'].value_counts()
# Out:
# [{'close': '2300', 'day': 1, 'open': '1030'}, {'close': '2300', 'day': 2, 'open': '1030'}, {'close': '2300', 'day': 3, 'open': '1030'}, {'close': '2300', 'day': 4, 'open': '1030'}, {'close': '2300', 'day': 5, 'open': '1030'}, {'close': '2300', 'day': 6, 'open': '1030'}, {'close': '2300', 'day': 7, 'open': '1030'}]                                                                                                                                                                                                                                                                                                                               8
# ...

# %%
brasil['website']
# Out:
# 0                                                   NaN
# 1                    http://www.pj-partners.com/tucano/
# 2                         http://www.pjgroup.jp/tucanos
# 3                             http://brasilicagrill.com
# 4                                http://www.la10.tokyo/
#                             ...
# 93    http://riogrande.createrestaurants.com/jp/yoko...
# 94    https://www.cial.co.jp/yokohama/floorguide/det...
# 95    http://riogrande.createrestaurants.com/jp/yoko...
# 96    http://riogrande.createrestaurants.com/jp/inde...
# 97    http://riogrande.createrestaurants.com/jp/yoko...
# Name: website, Length: 98, dtype: object

# %%
brasil['tips'].
# Out:
#   File "<ipython-input-104-0fa2718f95e8>", line 1
#     brasil['tips'].
#                    ^
# SyntaxError: invalid syntax

# %%
brasil['tips'].unique()
# Out:
# array(['[]',
#        '[{\'created_at\': \'2016-12-19T16:23:29.000Z\', \'text\': \'クイックシュラスコ980円！ 色々食べられる\'}, {\'created_at\': \'2016-02-07T08:46:44.000Z\', \'text\': "One of the best churrascarias in Tokyo! Really recommend the Papaya Cream dessert, don\'t forget to ask for the cassis topping!!"}]',
#        "[{'created_at': '2020-08-09T05:55:48.000Z', 'text': 'My 1000th place in Japan!'}, {'created_at': '2018-11-05T09:06:21.000Z', 'text': 'Souped up version of the original chain'}, {'created_at': '2016-02-02T02:51:30.000Z', 'text': 'Absolutely love this place, although it can be hard to get a reservation. Book well in advance!'}, {'created_at': '2016-01-01T09:40:33.000Z', 'text': 'a bit pricey'}, {'created_at': '2014-09-17T04:20:32.000Z', 'text': 'Honra o nome barbacoa. A carne estava excelente o o ponto perfeito.'}]",
# ...

# %%
brasil['tips'].isnull().sum()
# Out:
# 0

# %%
brasil['price'].unique()
# Out:
# array([ 2., nan])

# %%
brasil['price'].isnull().sum()
# Out:
# 40

# %%
brasil.drop(columns=['Unnamed: 0', 'chains', 'timezone', 'geocodes_roof_latitude', 'geocodes_roof_longitude', 'location_neighborhood', 'price', 
                   'verified', 'hours_is_local_holiday', 'hours_open_now', 'hours_seasonal', 'social_media_twitter', 
                   'hours_display', 'hours_regular', 'related_places_parent_fsq_id', 'related_places_parent_name','description', 
                   'social_media_facebook_id', 'website', 'social_media_instagram'], inplace=True)

# %%
data.columns
# Out:
# Index(['fsq_id', 'categories', 'distance', 'link', 'name',
#        'geocodes_main_latitude', 'geocodes_main_longitude', 'location_address',
#        'location_formatted_address', 'location_locality', 'location_postcode',
#        'location_region', 'popularity', 'rating', 'tastes', 'tips'],
#       dtype='object')

# %% [markdown]
# ### Duplicatas dentro das colunas

# %%
data.columns
# Out:
# Index(['fsq_id', 'categories', 'distance', 'link', 'name',
#        'geocodes_main_latitude', 'geocodes_main_longitude', 'location_address',
#        'location_formatted_address', 'location_locality', 'location_postcode',
#        'location_region', 'popularity', 'rating', 'tastes', 'tips'],
#       dtype='object')

# %%
data['location_locality'].sort_values().unique().tolist()
# Out:
# ['Akiruno',
#  'Atami',
#  'Chiba',
#  'Chichibu',
#  'Chiyoda',
#  'Chuo',
#  'Fuchu',
#  'Fussa',
#  'Gotenba-shi',
#  'Inagi-shi',
#  'Jōsō-shi',
#  'Kamisu',
#  'Kasukabe',
#  'Katsuura',
#  'Kawasaki',
#  'Kumagaya',
#  'Kōtō',
#  'Machida',
#  'Meguro',
#  'Minato',
#  'Mishima',
#  'Musashino',
#  'Narita',
#  'Saitama-shi',
#  'Shibayama-machi',
#  'Shibuya',
#  'Shiki',
#  'Shinagawa',
#  'Shinjuku',
#  'Tachikawa-shi',
#  'Tama',
#  'Tokorozawa',
#  'Tokyo',
#  'Urayasu',
#  'Utsunomiya',
#  'Yokohama',
#  'Ōta']

# %%
data['location_region'].sort_values().unique().tolist()
# Out:
# ['Chiba',
#  'Gunma',
#  'Ibaraki',
#  'Kanagawa',
#  'Saitama',
#  'Shizuoka',
#  'Tochigi',
#  'Tokyo']

# %%
brasil['location_locality'].sort_values().unique().tolist()
# Out:
# ['Chiyoda',
#  'Chuo',
#  "Jin'nan",
#  'Kawasaki',
#  'Minato',
#  'Narita',
#  'Narita-shi',
#  'Oota-ku',
#  'Roppongi',
#  'Shibuya',
#  'Shinjuku',
#  'Tachikawa-shi',
#  'Taitō',
#  'Tokyo',
#  'Toshima',
#  'Urayasu',
#  'Yokohama',
#  'Ōta']

# %%
brasil['location_region'].sort_values().unique().tolist()
# Out:
# ['Chiba', 'Kanagawa', 'Tokyo']

# %%
brasil['location_locality'][brasil['location_locality']=='Narita-shi'] = 'Narita'
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
brasil['location_locality'][brasil['location_locality']=='Narita-shi']
# Out:
# Series([], Name: location_locality, dtype: object)

# %%
brasil['location_locality'][brasil['location_locality']=='Narita']
# Out:
# 68    Narita
# 69    Narita
# 70    Narita
# 71    Narita
# Name: location_locality, dtype: object

# %% [markdown]
# ### Data

# %%
data
# Out:
#                       fsq_id  \
# 0   517fcb2be4b0d7e32b2c9a68
# 1   517089e9e4b0d21e986153c3
# 2   4f80f0bae4b0e160b9c9e122
# 3   598970be35f9830771f06b3f
# 4   5211312e11d259e1a2b3385a
# ..                       ...
# 90  6021eac0dc86d61c512b9d92
# 91  513805a1e4b032c75badf416
# 92  4dd0e28452b1f8915bd0e895
# 93  4c5d77ad94fd0f470665cb45
# 94  4ebb8e0577c8d9bd1b9358cb
#
#                                            categories  distance  \
# 0   [{'id': 19010, 'name': 'Bed and Breakfast', 'i...       932
# 1   [{'id': 19014, 'name': 'Hotel', 'icon': {'pref...      2776
# 2   [{'id': 19014, 'name': 'Hotel', 'icon': {'pref...      2480
# 3   [{'id': 19010, 'name': 'Bed and Breakfast', 'i...      3106
# 4   [{'id': 19014, 'name': 'Hotel', 'icon': {'pref...      1969
# ..                                                ...       ...
# 90  [{'id': 19014, 'name': 'Hotel', 'icon': {'pref...     31759
# 91  [{'id': 19014, 'name': 'Hotel', 'icon': {'pref...     34743
# ...

# %%
brasil
# Out:
#                       fsq_id  \
# 0   505fce2be4b0a054473fa2eb
# 1   b91c2784f0b44e826bdfef64
# 2   40a90c773f0d4e7d9b05426c
# 3   56738a44498e84771b21395a
# 4   e91ed07f7ad74c3ca56dfe6c
# ..                       ...
# 93  0cdac660a52e474cbae5cdbc
# 94  5f0d3896938b7c3b5e5fa837
# 95  0cdac660a52e474cbae5cdbc
# 96  535a620411d212a99bebe77b
# 97  0cdac660a52e474cbae5cdbc
#
#                                            categories  distance  \
# 0   [{'id': 13079, 'name': 'Brazilian Restaurant',...     734.0
# 1   [{'id': 13003, 'name': 'Bar', 'icon': {'prefix...     372.0
# 2   [{'id': 13031, 'name': 'Burger Joint', 'icon':...     383.0
# 3   [{'id': 13079, 'name': 'Brazilian Restaurant',...     432.0
# 4   [{'id': 13003, 'name': 'Bar', 'icon': {'prefix...     756.0
# ..                                                ...       ...
# 93  [{'id': 13026, 'name': 'BBQ Joint', 'icon': {'...     219.0
# 94  [{'id': 13079, 'name': 'Brazilian Restaurant',...     405.0
# ...

# %%
data.info()

# rating -> 28 Nulos
# tastes -> 60 Nulos
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95 entries, 0 to 94
# Data columns (total 16 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   fsq_id                      95 non-null     object
#  1   categories                  95 non-null     object
#  2   distance                    95 non-null     int64
#  3   link                        95 non-null     object
#  4   name                        95 non-null     object
#  5   geocodes_main_latitude      95 non-null     float64
#  6   geocodes_main_longitude     95 non-null     float64
#  7   location_address            95 non-null     object
#  8   location_formatted_address  95 non-null     object
#  9   location_locality           95 non-null     object
#  10  location_postcode           95 non-null     object
#  11  location_region             95 non-null     object
#  12  popularity                  95 non-null     float64
# ...

# %%
brasil.isnull().sum()

# location_cross_street -> 51 Nulos
# popularity -> 40 Nulos
# location_address_extended -> 60 Nulos
# rating -> 82 Nulos
# tastes -> 85 Nulos
# Out:
# fsq_id                         0
# categories                     0
# distance                       0
# link                           0
# name                           0
# geocodes_main_latitude         0
# geocodes_main_longitude        0
# location_address               0
# location_country               0
# location_cross_street         51
# location_formatted_address     0
# location_locality              0
# location_postcode              0
# location_region                0
# popularity                    40
# tips                           0
# hotel                          0
# hotel_latitude                 0
# hotel_longitude                0
# location_address_extended     60
# rating                        82
# tastes                        85
# dtype: int64

# %%
len(brasil.index)
# Out:
# 98

# %%
len(brasil.groupby(by='hotel'))
# Out:
# 37

# %%
brasil.groupby(by='hotel')['name'].count().sort_values(ascending=False)
# Out:
# hotel
# APA Hotel Shibuya Dogenzaka Ue (アパホテル渋谷道玄坂上)                              16
# THE BLOSSOM HIBIYA                                                         5
# Sotetsu Fresa Inn Shimbashi-Hibiyaguchi (相鉄フレッサイン新橋日比谷口)                   5
# Daiwa Roynet Hotel Yokohama-Kannai (ダイワロイネットホテル横浜関内)                       5
# APA HOTEL Keisei Narita-Ekimae (アパホテル 京成成田駅前)                              4
# Hotel New Green Okachimachi (ホテルニューグリーン御徒町)                                3
# Super Hotel Premier Tokyo-eki Yaesu Chuo-guchi (スーパーホテルLohas東京駅八重洲中央口)     3
# Sotetsu Fresa Inn (相鉄フレッサイン横浜駅東口)                                          3
# Hotel New Otani (ホテルニューオータニ)                                               3
# スカイスパYOKOHAMA                                                              3
# Anshin Oyado (安心お宿 秋葉原電気街店)                                                3
# Annex Tower (アネックスタワー)                                                     2
# ...

# %%
brasil[brasil['hotel']=='APA Hotel Shibuya Dogenzaka Ue (アパホテル渋谷道玄坂上)']
# Out:
#                       fsq_id  \
# 40  528af03311d281c7eee110d4
# 41  53c0fa87498e6127c41f69b1
# 42  51d7129f498e518d75167223
# 43  5368d16e498e8e238500d054
# 44  5b9a6f8ead910e002c2d47a1
# 45  5ac87cac04d1ae058febbd21
# 46  5beea7082b274a002ccc96bc
# 47  539b1659498ee5525ab6eac3
# 48  8c1c030fe8db4f5b6a601481
# 49  2691efd65ca7444f19a92ee0
# 50  ff915e0ec4c84c8648d26e48
# 51  2e0c7d1e80ac4e5af5542cb8
# 52  80a87675ad814375d1452b04
# 53  f5c84ef610c6433ce181aaac
# 54  80c3b7b93aaf40559a6d208a
# 55  b2bb0a119d9744d8e6afd263
#
#                                            categories  distance  \
# 40  [{'id': 13079, 'name': 'Brazilian Restaurant',...     724.0
# 41  [{'id': 13079, 'name': 'Brazilian Restaurant',...     395.0
# 42  [{'id': 13079, 'name': 'Brazilian Restaurant',...     299.0
# 43  [{'id': 13079, 'name': 'Brazilian Restaurant',...     358.0
# 44  [{'id': 13079, 'name': 'Brazilian Restaurant',...     436.0
# 45  [{'id': 13003, 'name': 'Bar', 'icon': {'prefix...     437.0
# ...
